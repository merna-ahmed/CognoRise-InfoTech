# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt


sns.set_style('whitegrid')
sns.set_palette('RdBu')

# %%
df= pd.read_csv('C:/Users/Merna Ahmed/Downloads/Unemployment in India.csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.shape
# Out:
# (768, 7)

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip() 
df
# Out:
#              Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 763             NaN          NaN       NaN                              NaN
# 764             NaN          NaN       NaN                              NaN
# 765             NaN          NaN       NaN                              NaN
# 766             NaN          NaN       NaN                              NaN
# 767             NaN          NaN       NaN                              NaN
#
# ...

# %%
df.isna().sum()
# Out:
# Region                                     28
# Date                                       28
# Frequency                                  28
# Estimated Unemployment Rate (%)            28
# Estimated Employed                         28
# Estimated Labour Participation Rate (%)    28
# Area                                       28
# dtype: int64

# %%
df.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
df.describe(include='object')
# Out:
#                 Region         Date Frequency   Area
# count              740          740       740    740
# unique              28           14         2      2
# top     Andhra Pradesh   31-10-2019   Monthly  Urban
# freq                28           55       381    381

# %%
df.rename(columns={' Estimated Unemployment Rate':'Estimated Unemployment Rate %'}, inplace=True)

df
# Out:
#              Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 763             NaN          NaN       NaN                              NaN
# 764             NaN          NaN       NaN                              NaN
# 765             NaN          NaN       NaN                              NaN
# 766             NaN          NaN       NaN                              NaN
# 767             NaN          NaN       NaN                              NaN
#
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763     True
# 764     True
# 765     True
# 766     True
# 767     True
# Length: 768, dtype: bool

# %%
df.duplicated().any()
# Out:
# np.True_

# %%
df.duplicated().sum()
# Out:
# np.int64(27)

# %%
df1=df[df.duplicated()]
df1
# Out:
#     Region Date Frequency  Estimated Unemployment Rate (%)  \
# 360    NaN  NaN       NaN                              NaN
# 361    NaN  NaN       NaN                              NaN
# 362    NaN  NaN       NaN                              NaN
# 363    NaN  NaN       NaN                              NaN
# 364    NaN  NaN       NaN                              NaN
# 365    NaN  NaN       NaN                              NaN
# 366    NaN  NaN       NaN                              NaN
# 367    NaN  NaN       NaN                              NaN
# 368    NaN  NaN       NaN                              NaN
# 369    NaN  NaN       NaN                              NaN
# 370    NaN  NaN       NaN                              NaN
# 371    NaN  NaN       NaN                              NaN
# 372    NaN  NaN       NaN                              NaN
# 754    NaN  NaN       NaN                              NaN
# 755    NaN  NaN       NaN                              NaN
# ...

# %%
null_rows=df[df.isnull().any(axis=1)]
null_rows
# Out:
#     Region Date Frequency  Estimated Unemployment Rate (%)  \
# 359    NaN  NaN       NaN                              NaN
# 360    NaN  NaN       NaN                              NaN
# 361    NaN  NaN       NaN                              NaN
# 362    NaN  NaN       NaN                              NaN
# 363    NaN  NaN       NaN                              NaN
# 364    NaN  NaN       NaN                              NaN
# 365    NaN  NaN       NaN                              NaN
# 366    NaN  NaN       NaN                              NaN
# 367    NaN  NaN       NaN                              NaN
# 368    NaN  NaN       NaN                              NaN
# 369    NaN  NaN       NaN                              NaN
# 370    NaN  NaN       NaN                              NaN
# 371    NaN  NaN       NaN                              NaN
# 372    NaN  NaN       NaN                              NaN
# 754    NaN  NaN       NaN                              NaN
# ...

# %%
df.dropna(inplace= True)
df
# Out:
#              Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
# ...

# %%
df.isna().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Area                                       0
# dtype: int64

# %%
df.shape
# Out:
# (740, 7)

# %%
df.sample(5)
# Out:
#          Region         Date Frequency  Estimated Unemployment Rate (%)  \
# 285  Tamil Nadu   29-02-2020   Monthly                             1.17
# 278  Tamil Nadu   31-07-2019   Monthly                             6.01
# 56        Delhi   31-07-2019   Monthly                            11.07
# 277  Tamil Nadu   30-06-2019   Monthly                             0.92
# 159   Karnataka   31-05-2020   Monthly                            23.72
#
#      Estimated Employed  Estimated Labour Participation Rate (%)   Area
# 285          15828488.0                                    48.86  Rural
# 278          16455928.0                                    53.94  Rural
# 56             166605.0                                    40.53  Rural
# 277          16375303.0                                    50.99  Rural
# 159          10626328.0                                    43.09  Rural

# %%
df['Region'].value_counts(normalize=True)* 100
# Out:
# Region
# Andhra Pradesh      3.783784
# Bihar               3.783784
# Chhattisgarh        3.783784
# Delhi               3.783784
# Karnataka           3.783784
# Gujarat             3.783784
# Haryana             3.783784
# Himachal Pradesh    3.783784
# Jharkhand           3.783784
# Maharashtra         3.783784
# Madhya Pradesh      3.783784
# Kerala              3.783784
# West Bengal         3.783784
# Uttar Pradesh       3.783784
# Tripura             3.783784
# Odisha              3.783784
# Rajasthan           3.783784
# Punjab              3.783784
# Telangana           3.783784
# Tamil Nadu          3.783784
# Uttarakhand         3.648649
# Meghalaya           3.648649
# Assam               3.513514
# Puducherry          3.513514
# Goa                 3.243243
# Jammu & Kashmir     2.837838
# Sikkim              2.297297
# Chandigarh          1.621622
# Name: proportion, dtype: float64

# %%
sns.histplot(df["Estimated Labour Participation Rate (%)"])
# Out:
# <Axes: xlabel='Estimated Labour Participation Rate (%)', ylabel='Count'>

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['Estimated Unemployment Rate (%)'])
plt.show()

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.displot(df['Estimated Employed'])
plt.show()

# %%
plt.bar('Region', 'Estimated Labour Participation Rate (%)' , data=df)
plt.title='Region by Estimated Labour Participation Rate (%)'
plt.xlabel='Region'
plt.ylabel='Estimated Labour Participation Rate (%)'
plt.xticks(rotation=90)
plt.show()

# %%
plt.bar('Area', 'Estimated Employed', data=df , color='green')
plt.title='Region by Estimated Employer'
plt.xlabel='Area'
plt.ylabel='Estimated Employed'
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='Region', y='Estimated Employed', data=df)
plt.title ='Boxplot of Estimated Employment by Region'
plt.xticks(rotation=90)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df['Month']=df['Date'].dt.month
df.inplace=True
df
# Out:
# C:\Users\Merna Ahmed\AppData\Local\Temp\ipykernel_20060\2723566353.py:1: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])
#              Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1    Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2    Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3    Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4    Andhra Pradesh 2019-09-30   Monthly                             5.17
# ..              ...        ...       ...                              ...
# 749     West Bengal 2020-02-29   Monthly                             7.55
# 750     West Bengal 2020-03-31   Monthly                             6.67
# ...

# %%
plt.plot('Estimated Unemployment Rate (%)','Year' , data=df )
plt.title='Daily unemployment rate  over years'
plt.xlabel='Estimated Unemployment Rate (%)'
plt.ylabel='Year'
plt.grid(True)

plt.show()

# %%
df['Area'].value_counts().plot.bar()
xlabel='Area'

# %%
unemployment_trend=df.groupby('Estimated Unemployment Rate (%)')['Month'].min(5).to_frame()
unemployment_trend
# Out:
#                                  Month
# Estimated Unemployment Rate (%)
# 0.00                                 2
# 0.24                                 9
# 0.37                                 8
# 0.41                                12
# 0.52                                 7
# ...                                ...
# 61.48                                4
# 70.17                                5
# 74.51                                4
# 75.00                                5
# 76.74                                4
#
# [624 rows x 1 columns]

# %%
employment_trend1=df.groupby('Estimated Employed')['Year'].max().to_frame()
employment_trend1
# Out:
#                     Year
# Estimated Employed
# 49420.0             2020
# 64538.0             2020
# 68122.0             2020
# 75456.0             2020
# 76269.0             2020
# ...                  ...
# 43298746.0          2019
# 44198762.0          2019
# 44257432.0          2020
# 44640087.0          2019
# 45777509.0          2020
#
# [740 rows x 1 columns]

# %%
df.groupby('Estimated Unemployment Rate (%)')['Year'].max(5).to_frame()
# Out:
#                                  Year
# Estimated Unemployment Rate (%)
# 0.00                             2020
# 0.24                             2019
# 0.37                             2019
# 0.41                             2019
# 0.52                             2019
# ...                               ...
# 61.48                            2020
# 70.17                            2020
# 74.51                            2020
# 75.00                            2020
# 76.74                            2020
#
# [624 rows x 1 columns]

# %%
df.sample()
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 2  Andhra Pradesh 2019-07-31   Monthly                             3.75
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  Month  \
# 2          12086707.0                                     43.5  Rural      7
#
#    Year
# 2  2019

# %%
df[['Estimated Labour Participation Rate (%)', 'Estimated Employed']].corr()
# Out:
#                                          Estimated Labour Participation Rate (%)  \
# Estimated Labour Participation Rate (%)                                   1.0000
# Estimated Employed                                                        0.0113
#
#                                          Estimated Employed
# Estimated Labour Participation Rate (%)              0.0113
# Estimated Employed                                   1.0000

# %%
df[['Estimated Unemployment Rate (%)', 'Estimated Employed']].corr()
# Out:
#                                  Estimated Unemployment Rate (%)  \
# Estimated Unemployment Rate (%)                         1.000000
# Estimated Employed                                     -0.222876
#
#                                  Estimated Employed
# Estimated Unemployment Rate (%)           -0.222876
# Estimated Employed                         1.000000

# %%
df.to_csv('C:/Users/Merna Ahmed/Downloads/Unemployment in India edit.csv')
